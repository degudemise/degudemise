# %% [markdown]
# <a href="https://colab.research.google.com/github/degudemise/degudemise/blob/main/Spatial_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas matplotlib
